# %% [markdown]
# <a href="https://colab.research.google.com/github/summerhasama/deeplearninga1/blob/main/a1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://images.squarespace-cdn.com/content/v1/50fb11f8e4b0dcfb3cb26d52/1628476344712-0709OOCM2HTVCD5JF409/amazing_dog_photography.jpg -O dog.jpg
# Out:
# --2023-02-15 09:41:08--  https://images.squarespace-cdn.com/content/v1/50fb11f8e4b0dcfb3cb26d52/1628476344712-0709OOCM2HTVCD5JF409/amazing_dog_photography.jpg
# Resolving images.squarespace-cdn.com (images.squarespace-cdn.com)... 151.101.0.238, 151.101.64.238, 151.101.128.238, ...
# Connecting to images.squarespace-cdn.com (images.squarespace-cdn.com)|151.101.0.238|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 677985 (662K) [image/jpeg]
# Saving to: ‘dog.jpg’
#
# dog.jpg             100%[===================>] 662.09K  --.-KB/s    in 0.02s
#
# 2023-02-15 09:41:08 (33.7 MB/s) - ‘dog.jpg’ saved [677985/677985]

# %%
# Importing Image from PIL package 
from PIL import Image
      
# creating a image object
image = Image.open("dog.jpg")

# resize image
width, height = image.size
image = image.resize((width//4, height//4)) 
  
image
# Out:
# <PIL.Image.Image image mode=RGB size=625x426 at 0x7FB118DBB730>

# %%
# change top right corner to black
width, height = image.size
for x in range(width-30,width):
  for y in range(0,30):
    image.putpixel( (x, y), (0, 0, 0, 255) )

image
# Out:
# <PIL.Image.Image image mode=RGB size=625x426 at 0x7FB118DBB730>
